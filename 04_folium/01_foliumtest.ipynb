# %%
import folium

# %%
m = folium.Map((37.5169837,126.8993953),zoom_start=16) #tiles='Stamen Watercolor'
# m.save('map.html')
folium.Marker((37.5169837,126.8993953),
              popup='문래역',
              tooltip='여기는 어디!!' ,
              icon=folium.Icon(icon="cloud"),).add_to(m)
folium.CircleMarker((37.5169837,126.8993953),
                    radius=20,
                    color='red',
                    fill_color='orange',
                    fill_opacity=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_620120fe3ecd61f575e68a5e337d04eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_620120fe3ecd61f575e68a5e337d04eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_620120fe3ecd61f575e68a5e337d04eb = L.map(
#                 &quot;map_620120fe3ecd61f575e68a5e337d04eb&quot;,
#                 {
#                     center: [37.5169837, 126.8993953],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5fd64b48adfc838379cbe225e4583a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_620120fe3ecd61f575e68a5e337d04eb);
#
#
#             var marker_d4fb53cb349eae438f68353dd8a74d3a = L.marker(
#                 [37.5169837, 126.8993953],
#                 {}
#             ).addTo(map_620120fe3ecd61f575e68a5e337d04eb);
#
#
#             var icon_cb74280e7a966e851e072d93bc636eea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d4fb53cb349eae438f68353dd8a74d3a.setIcon(icon_cb74280e7a966e851e072d93bc636eea);
#
#
#         var popup_af93da7470bc81d17034f92c604119c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89f9e7ce220b5f4a2ba47e005c7ed014 = $(`&lt;div id=&quot;html_89f9e7ce220b5f4a2ba47e005c7ed014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;문래역&lt;/div&gt;`)[0];
#                 popup_af93da7470bc81d17034f92c604119c5.setContent(html_89f9e7ce220b5f4a2ba47e005c7ed014);
#
#
#
#         marker_d4fb53cb349eae438f68353dd8a74d3a.bindPopup(popup_af93da7470bc81d17034f92c604119c5)
#         ;
#
#
#
#
#             marker_d4fb53cb349eae438f68353dd8a74d3a.bindTooltip(
#                 `&lt;div&gt;
#                      여기는 어디!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_923518d606e897daabf780d64339b856 = L.circleMarker(
#                 [37.5169837, 126.8993953],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_620120fe3ecd61f575e68a5e337d04eb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lotto = [
    {"store":"담배","loc":[37.62585944357624,127.01847823823798]},   
    {"store":"화곡본마트","loc":[37.54248103738589,126.84414659211494]},   
    {"store":"용꿈돼지꿈","loc":[37.5447438346992,126.95223862043447]},   
    {"store":"일이오마켓","loc":[37.47943673430032,126.98346178441342]},   
    {"store":"여명슈퍼마켓","loc":[37.61432815661055,127.0415039221072]},   
    {"store":"5가로또레드탑","loc":[37.570756251987575,127.00235901546226]},   
    {"store":"복권세상","loc":[35.91885025656432,128.55034430109828]},   
    {"store":"복권전문점","loc":[37.50384327747725,126.71513104367074]},   
    {"store":"인현동지하가판","loc":[37.47627910055104,126.63147671205866]},   
    {"store":"CU(광주서동점)","loc":[35.14814807640179,126.90555219336346]},   
    {"store":"지산로또방","loc":[35.148338888178,126.93203920504686]},   
    {"store":"천사로또방","loc":[37.63618838692431,127.21107884503209]},   
    {"store":"오렌지통신","loc":[37.42889361993242,127.10232604117991]},   
    {"store":"여수복권방","loc":[37.418353650942116,127.12640523182601]},   
    {"store":"둘리복권방","loc":[37.34532813934063,126.73627994929885]},   
    {"store":"금성24시편의점","loc":[37.84401249737699,127.06236893072152]},   
    {"store":"GS25(청주주은점)","loc":[36.60987111587086,127.49134026856717]},   
    {"store":"장미슈퍼","loc":[36.276304155315685,126.90940713047799]},   
    {"store":"장미슈퍼","loc":[36.276304155315685,126.90940713047799]},   
    {"store":"아이24(수송점)","loc":[35.970108052787594,126.7189421934312]},   
    {"store":"탑로또","loc":[34.87844231008963,128.62803523643754]} 
]

# %%
m = folium.Map((36.3279173,127.4444278),zoom_start=7)
for item in lotto:
    folium.Marker(item['loc'],tooltip=item['store']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_019cabbfeb28f009e55b1330d879e335 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_019cabbfeb28f009e55b1330d879e335&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_019cabbfeb28f009e55b1330d879e335 = L.map(
#                 &quot;map_019cabbfeb28f009e55b1330d879e335&quot;,
#                 {
#                     center: [36.3279173, 127.4444278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11b7460affb25958d93a75959996f528 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             var marker_92772d114591be5233e4d2986546b77c = L.marker(
#                 [37.62585944357624, 127.01847823823798],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_92772d114591be5233e4d2986546b77c.bindTooltip(
#                 `&lt;div&gt;
#                      담배
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0280ffb5f074ee9eec55cdb9c7d556bf = L.marker(
#                 [37.54248103738589, 126.84414659211494],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_0280ffb5f074ee9eec55cdb9c7d556bf.bindTooltip(
#                 `&lt;div&gt;
#                      화곡본마트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e704b36b2035653ec089febaf3fd34d = L.marker(
#                 [37.5447438346992, 126.95223862043447],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_3e704b36b2035653ec089febaf3fd34d.bindTooltip(
#                 `&lt;div&gt;
#                      용꿈돼지꿈
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c8fbba9d0702bdc0d272d8f0265a0820 = L.marker(
#                 [37.47943673430032, 126.98346178441342],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_c8fbba9d0702bdc0d272d8f0265a0820.bindTooltip(
#                 `&lt;div&gt;
#                      일이오마켓
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8dce48819857510e28a60e464f1e842f = L.marker(
#                 [37.61432815661055, 127.0415039221072],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_8dce48819857510e28a60e464f1e842f.bindTooltip(
#                 `&lt;div&gt;
#                      여명슈퍼마켓
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8c5e5279e0bea77b7b56aa96d3e876b0 = L.marker(
#                 [37.570756251987575, 127.00235901546226],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_8c5e5279e0bea77b7b56aa96d3e876b0.bindTooltip(
#                 `&lt;div&gt;
#                      5가로또레드탑
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f072bb5ae5de4b8a08c6b46cf16993b1 = L.marker(
#                 [35.91885025656432, 128.55034430109828],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_f072bb5ae5de4b8a08c6b46cf16993b1.bindTooltip(
#                 `&lt;div&gt;
#                      복권세상
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f647419103a2ba9c9d84fec42f1ede2c = L.marker(
#                 [37.50384327747725, 126.71513104367074],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_f647419103a2ba9c9d84fec42f1ede2c.bindTooltip(
#                 `&lt;div&gt;
#                      복권전문점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e91d9801131ec4deca82e5e733afa6d8 = L.marker(
#                 [37.47627910055104, 126.63147671205866],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);
#
#
#             marker_e91d9801131ec4deca82e5e733afa6d8.bindTooltip(
#                 `&lt;div&gt;
#                      인현동지하가판
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_46c1d6bbafc72e2d61505a05c4983beb = L.marker(
#                 [35.14814807640179, 126.90555219336346],
#                 {}
#             ).addTo(map_019cabbfeb28f009e55b1330d879e335);

# %%
from folium.plugins import MarkerCluster

# %%
m = folium.Map((36.3279173,127.4444278),zoom_start=7)
mc = MarkerCluster().add_to(m)
for item in lotto:
    folium.Marker(item['loc'],tooltip=item['store']).add_to(mc)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be3bf52f189dfd3c693973125a636497 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be3bf52f189dfd3c693973125a636497&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be3bf52f189dfd3c693973125a636497 = L.map(
#                 &quot;map_be3bf52f189dfd3c693973125a636497&quot;,
#                 {
#                     center: [36.3279173, 127.4444278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3760b5b3fdda90888659a97ee6ba1a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_be3bf52f189dfd3c693973125a636497);
#
#
#             var marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe = L.markerClusterGroup(
#                 {}
#             );
#             map_be3bf52f189dfd3c693973125a636497.addLayer(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             var marker_147730db31e79345ace60d3041c997d8 = L.marker(
#                 [37.62585944357624, 127.01847823823798],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_147730db31e79345ace60d3041c997d8.bindTooltip(
#                 `&lt;div&gt;
#                      담배
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_27eed3c7ec5fc5f338f43126cc0857c6 = L.marker(
#                 [37.54248103738589, 126.84414659211494],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_27eed3c7ec5fc5f338f43126cc0857c6.bindTooltip(
#                 `&lt;div&gt;
#                      화곡본마트
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0df8535d0d4c54c2b79fc0020d9efca3 = L.marker(
#                 [37.5447438346992, 126.95223862043447],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_0df8535d0d4c54c2b79fc0020d9efca3.bindTooltip(
#                 `&lt;div&gt;
#                      용꿈돼지꿈
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f971538bdf7f822ab66fa9f7b61a9375 = L.marker(
#                 [37.47943673430032, 126.98346178441342],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_f971538bdf7f822ab66fa9f7b61a9375.bindTooltip(
#                 `&lt;div&gt;
#                      일이오마켓
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10b1c029d4e4d6ee9e9fdce3528b5c56 = L.marker(
#                 [37.61432815661055, 127.0415039221072],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_10b1c029d4e4d6ee9e9fdce3528b5c56.bindTooltip(
#                 `&lt;div&gt;
#                      여명슈퍼마켓
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c5e4aed63199edd1805689a94b8d2ab6 = L.marker(
#                 [37.570756251987575, 127.00235901546226],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_c5e4aed63199edd1805689a94b8d2ab6.bindTooltip(
#                 `&lt;div&gt;
#                      5가로또레드탑
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d3b4e1e56e2c3710539b5f0d57414e2f = L.marker(
#                 [35.91885025656432, 128.55034430109828],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_d3b4e1e56e2c3710539b5f0d57414e2f.bindTooltip(
#                 `&lt;div&gt;
#                      복권세상
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8807c21ca9744df6385a98ac821cc867 = L.marker(
#                 [37.50384327747725, 126.71513104367074],
#                 {}
#             ).addTo(marker_cluster_07b99f11f3ec112afe3094b3ce51ddbe);
#
#
#             marker_8807c21ca9744df6385a98ac821cc867.bindTooltip(
#                 `&lt;div&gt;
#                      복권전문

# %%
import json

# %%
m = folium.Map((37.54833869931555,130.905463606694))
json_data = open('map.geojson','r').read()
json_data = json.loads(json_data)
folium.GeoJson(json_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb0643e53b56892bbb0b37537160df09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb0643e53b56892bbb0b37537160df09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb0643e53b56892bbb0b37537160df09 = L.map(
#                 &quot;map_fb0643e53b56892bbb0b37537160df09&quot;,
#                 {
#                     center: [37.54833869931555, 130.905463606694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7e67e058f6e95ef01bd588d3541f531 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb0643e53b56892bbb0b37537160df09);
#
#
#
#         function geo_json_0de785b0b482fef7903671a457a4056d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0de785b0b482fef7903671a457a4056d = L.geoJson(null, {
#                 onEachFeature: geo_json_0de785b0b482fef7903671a457a4056d_onEachFeature,
#
#         });
#
#         function geo_json_0de785b0b482fef7903671a457a4056d_add (data) {
#             geo_json_0de785b0b482fef7903671a457a4056d
#                 .addData(data)
#                 .addTo(map_fb0643e53b56892bbb0b37537160df09);
#         }
#             geo_json_0de785b0b482fef7903671a457a4056d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[130.905463606694, 37.54833869931555], [130.79433910925377, 37.515793230701135], [130.80696689305387, 37.503271961577795], [130.8019157795348, 37.48323356248453], [130.81075522819435, 37.47221015151483], [130.8530583039235, 37.46018275784738], [130.87389414719468, 37.45717560710291], [130.8959927688444, 37.475717776840966], [130.92503667158343, 37.48924564670992], [130.91367166616345, 37.510284131057844], [130.91493444454363, 37.54082946710395], [130.905463606694, 37.54833869931555]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
