# %%
import seaborn as sns

# %%
df = sns.load_dataset('anscombe')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
dataset1 = df[df['dataset']=='I']
dataset2 = df[df['dataset']=='II']
dataset3 = df[df['dataset']=='III']
dataset4 = df[df['dataset']=='IV']

# %%
dataset3
# Out:
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset1['x'],dataset1['y'],'o')

# %%
fig = plt.figure()
a1 = fig.add_subplot(2,2,1)
a2 = fig.add_subplot(2,2,2)
a3 = fig.add_subplot(2,2,3)
a4 = fig.add_subplot(2,2,4)
a1.plot(dataset1['x'],dataset1['y'],'o')
a2.plot(dataset2['x'],dataset2['y'],'o')
a3.plot(dataset3['x'],dataset3['y'],'o')
a4.plot(dataset4['x'],dataset4['y'],'o')

# %%
dataset1.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1148\148656524.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset1.mean()
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset2.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1148\3349088152.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset2.mean()
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset3.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1148\2152253674.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset3.mean()
# x    9.0
# y    7.5
# dtype: float64

# %%
dataset4.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1148\1693280217.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset4.mean()
# x    9.000000
# y    7.500909
# dtype: float64

# %%
dataset1.std()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1148\3261936497.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset1.std()
# x    3.316625
# y    2.031568
# dtype: float64

# %%
dataset1.corr()
# Out:
#           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
fig = plt.figure()
a1 = fig.add_subplot(1,1,1)
a1.hist(tips['total_bill'])
a1.set_title('Histgram of total bill')
a1.set_xlabel('Frequency')
a1.set_ylabel('total bill')
# Out:
# Text(0, 0.5, 'total bill')

# %%
fig1 = plt.figure()
a1 = fig1.add_subplot(1,1,1)
a1.scatter(tips['total_bill'],tips['tip'])
a1.set_title('scatterplot of total bill vs tip')
a1.set_xlabel('total bill')
a1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
fig2 = plt.figure()
a1 = fig2.add_subplot(1,1,1)
a1.boxplot([tips[tips['sex'] == 'Female']['tip'],
            tips[tips['sex'] == 'Male']['tip']],
           labels=['Female','Male'])
a1.set_title('Boxplot of tips by sex')
a1.set_xlabel('sex')
a1.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color']=tips['sex'].apply(recode_sex)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
fig3 = plt.figure()
a1 = fig3.add_subplot(1,1,1)
a1.scatter(tips['total_bill'],
           tips['tip'],
           s=tips['size']*10,
           c=tips['sex_color'],
           alpha=0.5,
          cmap='Accent')
a1.set_title('scatterplot of total bill vs tip')
a1.set_xlabel('total bill')
a1.set_ylabel('tip')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'],kde=True)
ax.set_title('total bill histgram')
# Out:
# Text(0.5, 1.0, 'total bill histgram')

# %%
ax = plt.subplots()
ax = sns.histplot(data=tips,x='total_bill',kde=True)
ax.set_title('total bill histgram')
# Out:
# Text(0.5, 1.0, 'total bill histgram')

# %%
sns.countplot(data=tips,x='day')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
day_list = ['Sun', 'mon','Tues','wed','Thur', 'Fri','Sat']

# %%
sns.countplot(data=tips,x='day',order=day_list)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>
