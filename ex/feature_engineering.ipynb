# %%
import pandas as pd
import numpy as np
import sys
import re

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

np.set_printoptions(threshold=sys.maxsize)

# %%
df = pd.read_csv('X_train.csv', encoding='cp949')

# %%
df.head()
# Out:
#           ID           직종          세부직종  \
# 0  SID100109  문화·예술·신문·방송  영상·음향·사진·카메라
# 1  SID100255  경영·기획·회계·사무      사무·총무·법무
# 2  SID100284        IT·게임  하드웨어설계·개발·관리
# 3  SID100315     영업·판매·TM          기술영업
# 4  SID100374     기술·과학·산업   기타 기술·과학·산업
#
#                                                 직무태그     근무경력 근무형태      근무지역  \
# 0                    취재기자, 편집 기사, 유아 사이트 기획, 시나리오 작성      0개월  NaN  서울,경기,서울
# 1                                                NaN  2년 11개월  정규직  부산,서울,일본
# 2  하드웨어 , 무선통신 , MICOM , ASM , RF , CDMA , Firm W...      0개월  NaN    서울,경기,
# 3                                                반도체   1년 0개월  정규직  경기,서울,충북
# 4                                                기술직      0개월  NaN  전국,전국,전국
#
#      출신대학   대학전공  어학시험 자격증  대학성적
# 0  성균관대학교     국문   NaN   無  70.0
# 1   신라대학교   관광경영  JLPT   無   NaN
# 2   수원대학교  정보통신공   NaN   有  60.0
# 3   수원대학교   정보통신   NaN   有  70.0
# 4   한밭대학교  화학공학과   NaN   無  70.0

# %%
df_s = df.sort_values(by=["대학전공"], ascending=[False]) 
df_s.head()
# Out:
#               ID           직종           세부직종  \
# 5110    SID31219     전문·교육·자격   경영분석·컨설팅·M&A
# 13194  SID682187  경영·기획·회계·사무  인사·노무·교육·인재개발
# 8185   SID463159          디자인         기타 디자인
# 16119  SID843380  재료·화학·섬유·의복          섬유·의복
# 14224  SID729210          디자인    의류·패션·잡화디자인
#
#                                          직무태그    근무경력 근무형태      근무지역     출신대학  \
# 5110                                       금융     0개월  NaN  서울,홍콩,경기   성균관대학교
# 13194          거래처관리,영업관리,영업지원,국내영업,기술영업,영업기획  2년 0개월  정규직  서울,경기,해외    용인대학교
# 8185   시각디자인,리빙디자인,photoShop,일러스트,디스플래이,광고디자인     0개월  NaN  서울,서울,서울    용인대학교
# 16119                        상품기획, 머천다이저, 디자인  8년 8개월  정규직      서울,,  이화여자대학교
# 14224                     섬유디자인,텍스타일디자인,소재디자인     0개월  정규직      서울,,  동덕여자대학교
#
#              대학전공 어학시험 자격증  대학성적
# 5110         회힉공학  NaN   無  60.0
# 13194        회화학과  NaN   有  80.0
# 8185         회화학과  NaN   無  70.0
# 16119        회화판화  NaN   無  80.0
# 14224  회화과 서양화 전공  NaN   無  60.0

# %%
df[df['대학전공'].isnull()] # 결측치 확인
# Out:
# Empty DataFrame
# Columns: [ID, 직종, 세부직종, 직무태그, 근무경력, 근무형태, 근무지역, 출신대학, 대학전공, 어학시험, 자격증, 대학성적]
# Index: []

# %%
df['대학전공'].value_counts()
# Out:
# 경영학                              774
# 경영학과                             450
# 경제학                              322
# 컴퓨터공학                            322
# 전자공학                             243
# 경영                               219
# 산업공학                             214
# 영어영문                             211
# 전자공학과                            207
# 기계공학                             197
# 행정학                              195
# 회계학                              188
# 무역학                              186
# 법학                               184
# 기계공학과                            179
# 경제학과                             175
# 컴퓨터공학과                           158
# 무역학과                             152
# 산업공학과                            152
# 산업디자인                            151
# 영어영문학                            146
# 의류학과                             137
# 화학                               136
# 시각디자인                            128
# 영어영문학과                           126
# ...

# %%
df['대학전공'].unique()
# Out:
# array(['국문', '관광경영', '정보통신공', '정보통신', '화학공학과', '컴퓨터공학', '사학', '일어일문',
#        '영어영문학과', '불어불문학과', '산업공학', '전산통계', '신문방송학', '생활미술', '문예창작', '무역',
#        '무역학과', '행정학과', '경영학부', '유통정보학과', '환경공학과', '영어영문', '국어/전산', '기계공학',
#        '컴퓨터공학과', '경제학', '경영정보', '물리학과', '전자공학과', '신문방송학과', '일본어', '정치외교',
#        '건축 공학과', '응용통계학', '경영/부전공:무역', '경영학', '전기전자공', '행정학', '전산과학',
#        '수학과', '산업안전공학', '의류학과', '법학과(중퇴)', '국어국문학', '컴퓨터정보공학', '재료/전자공학과',
#        '지역사회개발', '전자공학', '영어영문학', '기계공학과', '섬유공학과', '컴퓨터과학', '식품생명자원학',
#        '섬유예술학과', '산업공학과', '의상학', '전자재료공학과', '생명과학', '전자계산학', '경영', '신문방송',
#        '컴퓨터교육', '기계공악', '전자계산', '영문학', '신학과', '경영학과', '회계학과', '전산계산',
#        '사회복지', '금융보험학', '컴퓨터학과', '법학', '광고홍보학과', '전기공학', '사범대학유아교육과',
#        '정보통신공학과', '토목공학과', '간호학과', '회계', '중어중문', '회계학', '가정학과', '정치외교학',
#        '사범대학 일어교육과', '전산', '정보 경영학', '응용통계', '영어교육', '응용통계학과', '자원공학',
#        '식품영양학과', '금속재료', '제품디자인', '환경과학', '의류학', '한문학', '의류직물', '국어국문학과',
# ...

# %%
df['대학전공'].nunique()
# Out:
# 2030

# %%
df['대학전공'] = df['대학전공'].replace(' ', '') # 공백제거

# %%
df['대학전공'].unique()
# Out:
# array(['국문', '관광경영', '정보통신공', '정보통신', '화학공학과', '컴퓨터공학', '사학', '일어일문',
#        '영어영문학과', '불어불문학과', '산업공학', '전산통계', '신문방송학', '생활미술', '문예창작', '무역',
#        '무역학과', '행정학과', '경영학부', '유통정보학과', '환경공학과', '영어영문', '국어/전산', '기계공학',
#        '컴퓨터공학과', '경제학', '경영정보', '물리학과', '전자공학과', '신문방송학과', '일본어', '정치외교',
#        '건축 공학과', '응용통계학', '경영/부전공:무역', '경영학', '전기전자공', '행정학', '전산과학',
#        '수학과', '산업안전공학', '의류학과', '법학과(중퇴)', '국어국문학', '컴퓨터정보공학', '재료/전자공학과',
#        '지역사회개발', '전자공학', '영어영문학', '기계공학과', '섬유공학과', '컴퓨터과학', '식품생명자원학',
#        '섬유예술학과', '산업공학과', '의상학', '전자재료공학과', '생명과학', '전자계산학', '경영', '신문방송',
#        '컴퓨터교육', '기계공악', '전자계산', '영문학', '신학과', '경영학과', '회계학과', '전산계산',
#        '사회복지', '금융보험학', '컴퓨터학과', '법학', '광고홍보학과', '전기공학', '사범대학유아교육과',
#        '정보통신공학과', '토목공학과', '간호학과', '회계', '중어중문', '회계학', '가정학과', '정치외교학',
#        '사범대학 일어교육과', '전산', '정보 경영학', '응용통계', '영어교육', '응용통계학과', '자원공학',
#        '식품영양학과', '금속재료', '제품디자인', '환경과학', '의류학', '한문학', '의류직물', '국어국문학과',
# ...

# %%
# 1페이지

df['대학전공'] = df['대학전공'].replace(['경영학'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['경영'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['경영정보'], ['경영정보학과'])
df['대학전공'] = df['대학전공'].replace(['국문'], ['국문과'])
df['대학전공'] = df['대학전공'].replace(['관광경영'], ['관광경영과'])
df['대학전공'] = df['대학전공'].replace(['정보통신공'], ['정보통신공학과'])
df['대학전공'] = df['대학전공'].replace(['정보통신'], ['정보통신과'])
df['대학전공'] = df['대학전공'].replace(['화학공학과'], ['화학공학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터공학'], ['컴퓨터공학과'])
df['대학전공'] = df['대학전공'].replace(['사학'], ['사학과'])
df['대학전공'] = df['대학전공'].replace(['일어일문'], ['일어일문과'])
df['대학전공'] = df['대학전공'].replace(['산업공학'], ['산업공학과'])
df['대학전공'] = df['대학전공'].replace(['전산통계'], ['전산통계과'])
df['대학전공'] = df['대학전공'].replace(['신문방송학'], ['신문방송학과'])
df['대학전공'] = df['대학전공'].replace(['생활미술'], ['생활미술과'])
df['대학전공'] = df['대학전공'].replace(['문예창작'], ['문예창작과'])
df['대학전공'] = df['대학전공'].replace(['무역'], ['무역학과'])
df['대학전공'] = df['대학전공'].replace(['영어영문'], ['영어영문과'])
df['대학전공'] = df['대학전공'].replace(['국어/전산'], ['국어과'])
df['대학전공'] = df['대학전공'].replace(['기계공학'], ['기계공학과'])
df['대학전공'] = df['대학전공'].replace(['경제학'], ['경제학과'])
df['대학전공'] = df['대학전공'].replace(['경영정보'], ['경영정보과'])
df['대학전공'] = df['대학전공'].replace(['일본어'], ['일본어과'])
df['대학전공'] = df['대학전공'].replace(['정치외교'], ['정치외교과'])
df['대학전공'] = df['대학전공'].replace(['건축 공학과'], ['건축공학과'])
df['대학전공'] = df['대학전공'].replace(['응용통계학'], ['응용통계학과'])
df['대학전공'] = df['대학전공'].replace(['경영/부전공:무역'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['전기전자공'], ['전기전자공과'])
df['대학전공'] = df['대학전공'].replace(['행정학'], ['행정학과'])
df['대학전공'] = df['대학전공'].replace(['전산과학'], ['전산과학과'])
df['대학전공'] = df['대학전공'].replace(['산업안전공학'], ['산업안전공학과'])
df['대학전공'] = df['대학전공'].replace(['법학과(중퇴)'], ['법학과'])
df['대학전공'] = df['대학전공'].replace(['국어국문학'], ['국어국문학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터정보공학'], ['컴퓨터정보공학과'])
df['대학전공'] = df['대학전공'].replace(['재료/전자공학과'], ['전자공학과'])
df['대학전공'] = df['대학전공'].replace(['지역사회개발'], ['지역사회개발학과'])
df['대학전공'] = df['대학전공'].replace(['전자공학'], ['전자공학과'])
df['대학전공'] = df['대학전공'].replace(['영어영문학'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터과학'], ['컴퓨터과학과'])
df['대학전공'] = df['대학전공'].replace(['식품생명자원학'], ['식품생명자원학과'])
df['대학전공'] = df['대학전공'].replace(['의상학'], ['의상학과'])
df['대학전공'] = df['대학전공'].replace(['생명과학'], ['생명과학과'])
df['대학전공'] = df['대학전공'].replace(['전자계산'], ['전자계산학과'])
df['대학전공'] = df['대학전공'].replace(['전자계산학'], ['전자계산학과'])
df['대학전공'] = df['대학전공'].replace(['경영'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['신문방송'], ['신문방송과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터교육'], ['컴퓨터교육과'])
df['대학전공'] = df['대학전공'].replace(['기계공악'], ['기계공학과'])
df['대학전공'] = df['대학전공'].replace(['전자계산'], ['전자계산과'])
df['대학전공'] = df['대학전공'].replace(['영문학'], ['영문학과'])
df['대학전공'] = df['대학전공'].replace(['전자계산'], ['전자계산학과'])
df['대학전공'] = df['대학전공'].replace(['사회복지'], ['사회복지학과'])
df['대학전공'] = df['대학전공'].replace(['금융보험학'], ['금융보험학과'])
df['대학전공'] = df['대학전공'].replace(['법학'], ['법학과'])
df['대학전공'] = df['대학전공'].replace(['전기공학'], ['전기공학과'])
df['대학전공'] = df['대학전공'].replace(['사범대학유아교육과'], ['유아교육과'])
df['대학전공'] = df['대학전공'].replace(['회계'], ['회계학과'])
df['대학전공'] = df['대학전공'].replace(['중어중문'], ['중어중문학과'])
df['대학전공'] = df['대학전공'].replace(['회계학'], ['회계학과'])
df['대학전공'] = df['대학전공'].replace(['정치외교학'], ['정치외교학과'])
df['대학전공'] = df['대학전공'].replace(['사범대학 일어교육과'], ['일어교육과'])
df['대학전공'] = df['대학전공'].replace(['전산'], ['전산학과'])
df['대학전공'] = df['대학전공'].replace(['정보 경영학'], ['경영정보학과'])
df['대학전공'] = df['대학전공'].replace(['응용통계'], ['응용통계학과'])
df['대학전공'] = df['대학전공'].replace(['영어교육'], ['영어교육과'])
df['대학전공'] = df['대학전공'].replace(['자원공학'], ['자원공학과'])
df['대학전공'] = df['대학전공'].replace(['금속재료'], ['재료금속공학과'])
df['대학전공'] = df['대학전공'].replace(['제품디자인'], ['제품디자인과'])
df['대학전공'] = df['대학전공'].replace(['환경과학'], ['환경과학과'])
df['대학전공'] = df['대학전공'].replace(['의류학'], ['의류학과'])
df['대학전공'] = df['대학전공'].replace(['한문학'], ['한문학과'])
df['대학전공'] = df['대학전공'].replace(['의류직물'], ['의류직물과'])
df['대학전공'] = df['대학전공'].replace(['소프트웨어공학'], ['소프트웨어공학과'])
df['대학전공'] = df['대학전공'].replace(['영문'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['음악'], ['음악학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터학'], ['컴퓨터학과'])
df['대학전공'] = df['대학전공'].replace(['미생물공학, 경영학과(복수전공)'], ['미생물공학과'])
df['대학전공'] = df['대학전공'].replace(['시각디자인'], ['시각디자인학과'])
df['대학전공'] = df['대학전공'].replace(['도시공학'], ['도시공학과'])
df['대학전공'] = df['대학전공'].replace(['전산정보'], ['전산정보과'])
df['대학전공'] = df['대학전공'].replace(['국어국문'], ['국어국문학과'])
df['대학전공'] = df['대학전공'].replace(['무역학'], ['무역학과'])
df['대학전공'] = df['대학전공'].replace(['불어불문학'], ['불어불문학과'])
df['대학전공'] = df['대학전공'].replace(['화학공학'], ['화학공학과'])
df['대학전공'] = df['대학전공'].replace(['성악'], ['성악과'])
df['대학전공'] = df['대학전공'].replace(['산업디자인'], ['산업디자인과'])
df['대학전공'] = df['대학전공'].replace(['경영학 (경제학 부전공)'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['전자재료(전기전자공학부)'], ['전자재료과'])
df['대학전공'] = df['대학전공'].replace(['영어영문과'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['토목'], ['토목공학과'])
df['대학전공'] = df['대학전공'].replace(['전자물리'], ['전자물리학과'])
df['대학전공'] = df['대학전공'].replace(['물리'], ['물리학과'])
df['대학전공'] = df['대학전공'].replace(['제어계측'], ['제어계측공학과'])
df['대학전공'] = df['대학전공'].replace(['대기과학'], ['대기과학과'])
df['대학전공'] = df['대학전공'].replace(['원예학'], ['원예학과'])
df['대학전공'] = df['대학전공'].replace(['중국학'], ['중국학과'])
df['대학전공'] = df['대학전공'].replace(['멀티미디어정보처리'], ['멀티미디어공학과'])
df['대학전공'] = df['대학전공'].replace(['산업경제'], ['산업경제학과'])
df['대학전공'] = df['대학전공'].replace(['화학'], ['화학과'])
df['대학전공'] = df['대학전공'].replace(['철학'], ['철학과'])
df['대학전공'] = df['대학전공'].replace(['전산통계'], ['전산통계학과'])
df['대학전공'] = df['대학전공'].replace(['국민윤리학'], ['국민윤리학과'])
df['대학전공'] = df['대학전공'].replace(['심리학'], ['심리학과'])
df['대학전공'] = df['대학전공'].replace(['법'], ['법학과'])
df['대학전공'] = df['대학전공'].replace(['정보통신공학'], ['정보통신공학과'])
df['대학전공'] = df['대학전공'].replace(['한국화'], ['한국화과'])
df['대학전공'] = df['대학전공'].replace(['역사'], ['역사학과'])
df['대학전공'] = df['대학전공'].replace(['데이터정보'], ['데이터정보학과'])
df['대학전공'] = df['대학전공'].replace(['사범대 사회생활학과'], ['사회생활학과'])
df['대학전공'] = df['대학전공'].replace(['일어교육'], ['일어교육과'])
df['대학전공'] = df['대학전공'].replace(['광고홍보'], ['광고홍보학과'])
df['대학전공'] = df['대학전공'].replace(['독어독문학'], ['독어독문학과'])
df['대학전공'] = df['대학전공'].replace(['환경'], ['환경학과'])
df['대학전공'] = df['대학전공'].replace(['장식미술(복식디자인)'], ['장식미술학과'])
df['대학전공'] = df['대학전공'].replace(['동물자원학(축산학)'], ['동물자원학과'])
df['대학전공'] = df['대학전공'].replace(['문헌정보학'], ['문헌정보학과'])
df['대학전공'] = df['대학전공'].replace(['전자통신'], ['전자통신공학과'])
df['대학전공'] = df['대학전공'].replace(['사회학'], ['사회학과'])
df['대학전공'] = df['대학전공'].replace(['정보통신학'], ['정보통신학과'])
df['대학전공'] = df['대학전공'].replace(['섬유예술'], ['섬유예술과'])
df['대학전공'] = df['대학전공'].replace(['메카트로닉스 공학과'], ['메카트로닉스공학과'])
df['대학전공'] = df['대학전공'].replace(['가족경영 소비자 학과'], ['소비자학과'])
df['대학전공'] = df['대학전공'].replace(['수학'], ['수학과'])
df['대학전공'] = df['대학전공'].replace(['금융보험'], ['금융보험학과'])
df['대학전공'] = df['대학전공'].replace(['정보공학'], ['정보공학과'])
df['대학전공'] = df['대학전공'].replace(['수학, 컴퓨터공학'], ['수학과'])
df['대학전공'] = df['대학전공'].replace(['기계설계'], ['기계설계과'])
df['대학전공'] = df['대학전공'].replace(['동물자원학'], ['동물자원학과'])
df['대학전공'] = df['대학전공'].replace(['물리학'], ['물리학과'])
df['대학전공'] = df['대학전공'].replace(['금속공학'], ['금속공학과'])
df['대학전공'] = df['대학전공'].replace(['호텔경영'], ['호텔경영학과'])
df['대학전공'] = df['대학전공'].replace(['화학,전기전자 복수전공'], ['화학과'])
df['대학전공'] = df['대학전공'].replace(['서양화전공'], ['서양화과'])
df['대학전공'] = df['대학전공'].replace(['섬유조형디자인'], ['섬유조형디자인과'])
df['대학전공'] = df['대학전공'].replace(['행정'], ['행정학과'])
df['대학전공'] = df['대학전공'].replace(['의상디자인'], ['의상디자인학과'])
df['대학전공'] = df['대학전공'].replace(['산업디자인 시각미디어전공'], ['산업디자인학과'])

# %%
# 2페이지

df['대학전공'] = df['대학전공'].replace(['무용'], ['무용학과'])
df['대학전공'] = df['대학전공'].replace(['동양어문학'], ['동양어문학과'])
df['대학전공'] = df['대학전공'].replace(['불어교육'], ['불어교육과'])
df['대학전공'] = df['대학전공'].replace(['전자재료공학'], ['전자재료공학과'])
df['대학전공'] = df['대학전공'].replace(['식품영양학'], ['식품영양학과'])
df['대학전공'] = df['대학전공'].replace(['독어독문'], ['독어독문학과'])
df['대학전공'] = df['대학전공'].replace(['건축공학'], ['건축공학과'])
df['대학전공'] = df['대학전공'].replace(['수학/컴퓨터'], ['수학과'])
df['대학전공'] = df['대학전공'].replace(['독일어'], ['독일어과'])
df['대학전공'] = df['대학전공'].replace(['국제통상'], ['국제통상학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터'], ['컴퓨터학과'])
df['대학전공'] = df['대학전공'].replace(['보건관리학'], ['보건관리학과'])
df['대학전공'] = df['대학전공'].replace(['생명공학'], ['생명공학과'])
df['대학전공'] = df['대학전공'].replace(['불어불문'], ['불어불문과'])
df['대학전공'] = df['대학전공'].replace(['무대디자인'], ['무대디자인과'])
df['대학전공'] = df['대학전공'].replace(['섬유공학/의상학'], ['섬유공학과'])
df['대학전공'] = df['대학전공'].replace(['의상'], ['의상학과'])
df['대학전공'] = df['대학전공'].replace(['광고홍보학'], ['광고홍보학과'])
df['대학전공'] = df['대학전공'].replace(['영어'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['일어일문학'], ['일어일문학과'])
df['대학전공'] = df['대학전공'].replace(['동양화'], ['동양화과'])
df['대학전공'] = df['대학전공'].replace(['국제경제'], ['국제경제학과'])
df['대학전공'] = df['대학전공'].replace(['영상학'], ['영상학과'])
df['대학전공'] = df['대학전공'].replace(['조형예술'], ['조형예술학과'])
df['대학전공'] = df['대학전공'].replace(['부동산학'], ['부동산학과'])
df['대학전공'] = df['대학전공'].replace(['유아교육학'], ['유아교육학과'])
df['대학전공'] = df['대학전공'].replace(['정보시스템'], ['정보시스템학과'])
df['대학전공'] = df['대학전공'].replace(['재무금융'], ['재무금융학과'])
df['대학전공'] = df['대학전공'].replace(['일본어교육'], ['일본어교육과'])
df['대학전공'] = df['대학전공'].replace(['공학계열'], ['공과'])
df['대학전공'] = df['대학전공'].replace(['유통정보학'], ['유통정보학과'])
df['대학전공'] = df['대학전공'].replace(['가정관리'], ['가정관리학과'])
df['대학전공'] = df['대학전공'].replace(['컴퓨터 공학'], ['컴퓨터공학과'])
df['대학전공'] = df['대학전공'].replace(['고분자공(신소재공학)'], ['신소재공학과'])
df['대학전공'] = df['대학전공'].replace(['광고,시각'], ['광고학과'])
df['대학전공'] = df['대학전공'].replace(['교육학'], ['교육학과'])
df['대학전공'] = df['대학전공'].replace(['전산공학'], ['전산공학과'])
df['대학전공'] = df['대학전공'].replace(['사회체육'], ['사회체육과'])
df['대학전공'] = df['대학전공'].replace(['생화학'], ['생화학과'])
df['대학전공'] = df['대학전공'].replace(['정보전산'], ['정보전산과'])
df['대학전공'] = df['대학전공'].replace(['경상대 응용통계'], ['응용통계학과'])
df['대학전공'] = df['대학전공'].replace(['생물'], ['생물학과'])
df['대학전공'] = df['대학전공'].replace(['독문,심리'], ['독어독문학과'])
df['대학전공'] = df['대학전공'].replace(['지구과학'], ['지구과학과'])
df['대학전공'] = df['대학전공'].replace(['어학연수'], ['기타'])
df['대학전공'] = df['대학전공'].replace(['산업심리'], ['산업심리학과'])
df['대학전공'] = df['대학전공'].replace(['산업경영공학'], ['산업경영공학과'])
df['대학전공'] = df['대학전공'].replace(['섬유공예'], ['섬유공예과'])
df['대학전공'] = df['대학전공'].replace(['교육공학'], ['교육공학과'])
df['대학전공'] = df['대학전공'].replace(['아동복지'], ['아동복지학과'])
df['대학전공'] = df['대학전공'].replace(['산업시스템'], ['산업시스템공학과'])
df['대학전공'] = df['대학전공'].replace(['경영/회계'], ['경영학과'])
df['대학전공'] = df['대학전공'].replace(['체육학'], ['체육학과'])
df['대학전공'] = df['대학전공'].replace(['일어일본학'], ['일어일문학과'])
df['대학전공'] = df['대학전공'].replace(['영어학'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['지역개발학'], ['지역개발학과'])
df['대학전공'] = df['대학전공'].replace(['전자공'], ['전자공학과'])
df['대학전공'] = df['대학전공'].replace(['가족문화소비자학'], ['가족문화소비자학과'])
df['대학전공'] = df['대학전공'].replace(['스포츠과학'], ['스포츠과학과'])
df['대학전공'] = df['대학전공'].replace(['광고정보'], ['광고정보학과'])
df['대학전공'] = df['대학전공'].replace(['러시아어'], ['러시아어학과'])
df['대학전공'] = df['대학전공'].replace(['정치행정'], ['정치행정학과'])
df['대학전공'] = df['대학전공'].replace(['토목공학'], ['토목공학과'])
df['대학전공'] = df['대학전공'].replace(['경제무역'], ['경제무역과'])
df['대학전공'] = df['대학전공'].replace(['산업공예'], ['산업공예과'])
df['대학전공'] = df['대학전공'].replace(['동물영양자원'], ['동물영양자원과'])
df['대학전공'] = df['대학전공'].replace(['교육/영문'], ['영어영문학과'])
df['대학전공'] = df['대학전공'].replace(['패션디자인'], ['패션디자인과'])
df['대학전공'] = df['대학전공'].replace(['유통정보'], ['유통정보과'])
df['대학전공'] = df['대학전공'].replace(['독일어교육'], ['독일어교육학과'])
df['대학전공'] = df['대학전공'].replace(['경제'], ['경제학과'])
df['대학전공'] = df['대학전공'].replace(['보건관리'], ['보건관리과'])
df['대학전공'] = df['대학전공'].replace(['신학/기독교교육학'], ['기독교교육학과'])
df['대학전공'] = df['대학전공'].replace(['통계(경영)'], ['통계학과'])
df['대학전공'] = df['대학전공'].replace(['응용화학'], ['응용화학과'])
df['대학전공'] = df['대학전공'].replace(['식품공학'], ['식품공학과'])
df['대학전공'] = df['대학전공'].replace(['중어중문학'], ['중어중문학과'])
df['대학전공'] = df['대학전공'].replace(['고분자'], ['고분자공학과'])
df['대학전공'] = df['대학전공'].replace(['무기재료'], ['무기재료공학과'])
df['대학전공'] = df['대학전공'].replace(['지식정보'], [''])

# %%
df['대학전공'].value_counts()
# Out:
# 경영학과                             1444
# 경제학과                              497
# 컴퓨터공학과                            480
# 전자공학과                             451
# 기계공학과                             376
# 산업공학과                             366
# 행정학과                              273
# 영어영문학과                            272
# 무역학과                              263
# 영어영문과                             217
# 회계학                               188
# 무역학                               186
# 법학                                184
# 전자계산학과                            176
# 산업디자인                             151
# 의류학과                              137
# 화학                                136
# 시각디자인                             128
# 회계학과                              122
# 중어중문                              121
# 국어국문학과                            116
# 화학공학                              115
# 화학공학과                             112
# 정보통신공학                            109
# 전기공학과                             108
# ...

# %%
df['대학전공'].str.replace()
# Out:
# 0                                  국문과
# 1                                관광경영과
# 2                              정보통신공학과
# 3                                정보통신과
# 4                                화학공학과
# 5                               컴퓨터공학과
# 6                                  사학과
# 7                                일어일문과
# 8                               영어영문학과
# 9                               불어불문학과
# 10                               산업공학과
# 11                               전산통계과
# 12                              신문방송학과
# 13                               생활미술과
# 14                               생활미술과
# 15                               문예창작과
# 16                                무역학과
# 17                                무역학과
# 18                                행정학과
# 19                                경영학부
# 20                              유통정보학과
# 21                               환경공학과
# 22                              영어영문학과
# 23                                 국어과
# ...

# %%
df['대학전공']=df[df['대학전공'].str.contains('자원경제학')][['대학전공']]

# %%
df[df['대학전공'].str.contains('자원경제학')][['대학전공']]
# Out:
# ---------------------------------------------------
# ValueError        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2892\3776697904.py in <module>
# ----> 1 df[df['대학전공'].str.contains('자원경제학')][['대학전공']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
# -> 3495         if com.is_bool_indexer(key):
#    3496             return self._getitem_bool_array(key)
#    3497
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     142                     # Don't raise on e.g. ["A", "B", np.nan], see
#     143                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 144                     raise ValueError(na_msg)
#     145                 return False
#     146             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df['대학전공'].unique()
# Out:
# array(['국문과', '관광경영과', '정보통신공학과', '정보통신과', '화학공학과', '컴퓨터공학과', '사학과',
#        '일어일문과', '영어영문학과', '불어불문학과', '산업공학과', '전산통계과', '신문방송학과', '생활미술과',
#        '문예창작과', '무역학과', '행정학과', '경영학부', '유통정보학과', '환경공학과', '영어영문과', '국어과',
#        '기계공학과', '경제학과', '경영정보학과', '물리학과', '전자공학과', '일본어과', '정치외교과',
#        '건축공학과', '응용통계학과', '경영학과', '전기전자공과', '전산과학과', '수학과', '산업안전공학과',
#        '의류학과', '법학과', '국어국문학과', '컴퓨터정보공학과', '지역사회개발학과', '섬유공학과', '컴퓨터과학과',
#        '식품생명자원학과', '섬유예술학과', '의상학과', '전자재료공학과', '생명과학과', '전자계산학', '신문방송',
#        '컴퓨터교육', '기계공악', '전자계산학과', '영문학', '신학과', '회계학과', '전산계산', '사회복지',
#        '금융보험학', '컴퓨터학과', '법학', '광고홍보학과', '전기공학', '사범대학유아교육과', '토목공학과',
#        '간호학과', '회계', '중어중문', '회계학', '가정학과', '정치외교학', '사범대학 일어교육과', '전산',
#        '정보 경영학', '응용통계', '영어교육', '자원공학', '식품영양학과', '금속재료', '제품디자인',
#        '환경과학', '의류학', '한문학', '의류직물', '사회교육학과', '소프트웨어공학', '영문', '음악학',
#        '컴퓨터학', '미생물공학, 경영학과(복수전공)', '전기공학과', '시각디자인', '도시공학', '전산정보',
# ...

# %%
# df3.loc[df3['suicided']==True, 'suicided']

# %%
# 소문자 찾는법 listing[listing['Name'].str.contains('kodex',case=False)] case False를 넣어준다.

# %%
# df3[df3['prior_signs_mental_health_issues'].isnull()]['prior_signs_mental_health_issues']

# %%
# busan['동'] = busan['동'].replace(['거1동', '거2동', '거3동', '거4동'], ['거제1동','거제2동','거제3동','거제4동'])

# %%
# data['일반현황'].apply(lambda x : int(re.search('([0-9]{4,})',x).group()))

# 숫자 4개 이상인 것. ([0-9]{4,}) 이 패턴을 x에서 찾는다 그룹은 해당하는 것을 그룹 int화해서 결과값으로 나오는 것이다.
